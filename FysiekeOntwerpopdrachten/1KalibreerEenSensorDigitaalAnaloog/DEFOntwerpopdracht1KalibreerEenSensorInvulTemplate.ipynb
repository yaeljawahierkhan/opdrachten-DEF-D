# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 29     |  |
# | :-------------|:-------------|
# | Student Yael Jawahierkhan | 6444504 |
# | Student Simon Baur| 6217788 |
# | Student Carice von Morgen| 6452892 |
#
# | Planning Groep: XX     |Tijdstip / Tijdspanne  |
# |---|---|
# | Mijlpaal 1: Criteria opgesteld | 12:00 |
# | Mijlpaal 2: Eerste kalibratie meting gedaan| 12:30 |
# | Pauze 1| 13:30 |
# | Pauze 2| 15:30 |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# <img src="1.jpeg" alt="Alt" title="analyse: ideeen" width="30%">
# <img src="2.jpeg" alt="Alt" title="analyse: ideeen" width="30%">
# <img src="3.jpeg" alt="Alt" title="analyse: ideeen" width="30%">
# <img src="4.jpeg" alt="Alt" title="analyse: ideeen" width="30%">
# <img src="5.jpeg" alt="Alt" title="analyse: ideeen" width="30%">
# <img src="6.jpeg" alt="Alt" title="analyse: ideeen" width="30%">
# <img src="7.jpeg" alt="Alt" title="analyse: ideeen" width="30%">

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |Lichtsensor | Meten helderheid laptop | Meten range licht intensiteit (nits) van een laptop helderheid, de sensor moet een onderscheid kunnen maken tussen 200 en 500 nits, met nauwkeurigheid 2 nits. En bepalen verschil tussen niet verlichte kamer en verlichte kamer door laptop. (Deze metingen worden gedaan op 10cm afstand tussen laptop en sensor)|
# |Krachtsensor | Kijken welke TA het hardst kan knijpen |Kan knijpkracht indexeren, en kan verschil in knijpkracht meten. Dit moet in een range van 0 tot 15N, met een onzekerheid van 0.1N|
# |Temperatuursensor | De warmte van iemands adem tegenover huidtemperatuur meten. | Nauwkeurig tot 1 decimaal celius verschil kunnen meten tussen huidwarmte (Vingers) en Adem-warmte (5cm tussen mond en sensor) We verwachten een temperatuur van 30 - 45 graden C |
#
#
# Groep 29 heeft gekozen voor kracht sensor.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# In de foto is de schets van de opstelling te zien.
# <img src="8.jpeg" alt="Alt" title="Schets gekozen project" width="30%">

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen? \
# Het gewicht op de sensor en de weegschaal
#
# 2. Over welk bereik ga je deze variabelen veranderen? \
# 0-0.4kg
#
# 3. Wat ga je allemaal meten?\
#  Het gewicht en de output uit de arduino
#
# 4. Hoeveel metingen ga je doen?\
#  10 metingen.
#
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen? \
# Als er een beschrijfbaar verband is tussen de output van de arduino en het gewicht gemeten op de weegschaal is het geschikt.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Eerste meetopstelling
# <img src="9.jpeg" alt="Alt" title="Schets gekozen project" width="30%">
# <img src="10.jpeg" alt="Alt" title="Schets gekozen project" width="30%">

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

A_data = np.array([
    20, 32, 40, 48, 57,
    78, 82, 88, 92, 94, 98,
    111, 115, 117, 119, 131
])

W_data = np.array([
     47.84,
     95.69,
    143.54,
    192.55,
    240.40,
    432.90,
    480.75,
    529.76,
    577.60,
    625.45,
    673.30,
    998.20,
   1046.05,
   1095.06,
   1142.90,
   1452.60
])*9.81/1000

# %%
def lineare_fit(x, a):
    return a * x**0.5

val, cov = curve_fit(lineare_fit, W_data, A_data)

x_test = np.arange(max(W_data) + 10)

plt.figure()
plt.plot(W_data, A_data, 'k.')
plt.errorbar(W_data, A_data, yerr=1,xerr=9.81/1000, fmt='k.', capsize=5)
plt.plot(x_test, lineare_fit(x_test, *val), 'r--')
plt.xlabel('Kracht [N]')
plt.ylabel('Waarde van arduino')
plt.show()

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# We hebben een paar iteraties gedaan, we hebben meer metingen en een grotere range dan verwacht. En de opstelling is ook veranderd van de ductape naar een bak waar we de ducttape in konden zetten (zie foto hieronder). We vonden dat dit nodig was voor betere meetpunten, en voor de lagere meetpunten hebben we een papieren bakje gebruikt met battrijen(zie foto hieronder), we vonden lagere meetpunten essentieel om het wortel verband te visualizeren. (als we fitten met a*x**n dan is n ongeveer 0.5, dus we denken dat een wortel de kracht op deze sensor beschrijft.)
#
# <img src="11.jpeg" alt="Alt" title="Schets gekozen project" width="30%">
# <img src="12.jpeg" alt="Alt" title="Schets gekozen project" width="30%">

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
# Omdat we een wortel verband (een continue stijgende functie) hebben gevonden tussen het gewicht op de sensor en de output is deze sensor geschikt om de knijpkracht van mensen te rangschikken. Ook heeft de grafiek een range tussen de 0 en 15N en is de onzekerheid binnen de 0.1N dus voldoet het aan de criteria.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# In de foto is de schets van de opstelling te zien.
# <img src="8.jpeg" alt="Alt" title="Schets gekozen project" width="30%">
#
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Eerste opstelling (en het circuit boven).
# <img src="9.jpeg" alt="Alt" title="Schets gekozen project" width="30%">
# <img src="10.jpeg" alt="Alt" title="Schets gekozen project" width="30%">

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |Lichtsensor | Meten helderheid laptop | Meten range licht intensiteit (nits) van een laptop helderheid, de sensor moet een onderscheid kunnen maken tussen 200 en 500 nits, met nauwkeurigheid 2 nits. En bepalen verschil tussen niet verlichte kamer en verlichte kamer door laptop. (Deze metingen worden gedaan op 10cm afstand tussen laptop en sensor)|
# |Krachtsensor | Kijken welke TA het hardst kan knijpen |Kan knijpkracht indexeren, en kan verschil in knijpkracht meten. Dit moet in een range van 0 tot 15N, met een onzekerheid van 0.1N|
# |Temperatuursensor | De warmte van iemands adem tegenover huidtemperatuur meten. | Nauwkeurig tot 1 decimaal celius verschil kunnen meten tussen huidwarmte (Vingers) en Adem-warmte (5cm tussen mond en sensor) We verwachten een temperatuur van 30 - 45 graden C |
#
#
# Groep 29 heeft gekozen voor kracht sensor.

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Eerste opstelling.
# <img src="9.jpeg" alt="Alt" title="Schets gekozen project" width="30%">
# <img src="10.jpeg" alt="Alt" title="Schets gekozen project" width="30%">
#
# ## *Opdracht 8*: Conclusie, leerdoel
# Omdat we een wortel verband  (een continue stijgende functie) hebben gevonden tussen het gewicht op de sensor en de output is deze sensor geschikt om de knijpkracht van mensen te rangschikken. Dus een hogere output uit de krachtsensor betekend een hogere knijpkracht. De opstelling is geschikt om binnen de gewenste onzekerheden te meten.

# %%
def lineare_fit(x, a):
    return a * x**0.5

val, cov = curve_fit(lineare_fit, W_data, A_data)

x_test = np.arange(max(W_data) + 10)

plt.figure()
plt.plot(W_data, A_data, 'k.')
plt.errorbar(W_data, A_data, yerr=1,xerr=1, fmt='k.', capsize=5)
plt.plot(x_test, lineare_fit(x_test, *val), 'r--')
plt.xlabel('Gewicht (g)')
plt.ylabel('Waarde van arduino')
plt.show()
